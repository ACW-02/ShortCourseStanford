# %% [markdown]
# ### **Network Analysis**

# %% [markdown]
# <font color="red">File access required:</font> In Colab this notebook requires first uploading files **Friends.csv**, **Follows.csv**, and **Dolphins.csv** using the *Files* feature in the left toolbar. If running the notebook on a local computer, simply ensure these files are in the same workspace as the notebook.

# %%
# Setup
import csv
import matplotlib.pyplot as plt
# %matplotlib inline
import networkx as nx

# %% [markdown]
# **Look at CSV files:** node pairs

# %% [markdown]
# ### Undirected graph (Friends)

# %%
# Load graph from CSV file with no header
f = open('Friends.csv')
G = nx.read_edgelist(f, delimiter=',', nodetype=str)
print(G)
# Out:
# Graph with 10 nodes and 15 edges

# %%
# Display graph
# First two lines size drawing for Jupyter notebook
# Note layout differs each time
plt.figure(figsize=(7,7))
plt.margins(x=0.1, y=0.1)
nx.draw(G, with_labels=True, node_size=1500, node_color='c')

# %%
# Density of graph
numnodes = G.number_of_nodes()
numedges = G.number_of_edges()
possedges = G.number_of_nodes() * (G.number_of_nodes()-1) / 2
print('Number of nodes:', numnodes)
print('Number of edges:', numedges)
print('Possible edges:', possedges)
print('Density (edges divided by possible edges):', numedges/possedges)
# Out:
# Number of nodes: 10
# Number of edges: 15
# Possible edges: 45.0
# Density (edges divided by possible edges): 0.3333333333333333

# %%
# Did previous cell get right answer?
print('Using density function:', nx.density(G))
# Out:
# Using density function: 0.3333333333333333

# %%
# Diameter and overall average shortest distance
print('Diameter:', nx.diameter(G))
print('Average shortest distance:', nx.average_shortest_path_length(G))
# Out:
# Diameter: 4
# Average shortest distance: 2.022222222222222

# %%
# Maximal cliques
cliques = nx.find_cliques(G) # cliques is iterator
for c in cliques:
    print(c)
# Try print cliques
# Modify code to only print cliques > 2
# Out:
# ['Emma', 'Josh', 'Aaron']
# ['Emma', 'Sarah']
# ['Chris', 'Mike']
# ['Chris', 'Jane']
# ['Chris', 'Sarah', 'Drew']
# ['Chris', 'Aaron']
# ['Sam', 'Jane']
# ['Jess', 'Josh', 'Mike']
# ['Jess', 'Josh', 'Aaron']

# %%
# Iterating through nodes of the graph
for n in G:
    print(n)
# Out:
# Aaron
# Chris
# Emma
# Josh
# Drew
# Jane
# Jess
# Mike
# Sarah
# Sam

# %%
# Number of friends -'degree' is number of edges incident on a node
numfriends = G.degree
print(numfriends)
# for n in numfriends:
#    print(n[0], 'has', n[1], 'friends')
# Or can treat list of pairs like a dictionary
# for n in G:
#    print(n, 'has', numfriends[n], 'friends')
# Out:
# [('Aaron', 4), ('Chris', 5), ('Emma', 3), ('Josh', 4), ('Drew', 2), ('Jane', 2), ('Jess', 3), ('Mike', 3), ('Sarah', 3), ('Sam', 1)]

# %%
# Friends lists
for n in G:
    print(n, 'has friends:')
    friends = G.neighbors(n) # friends is iterator
    for f in friends:
        print(' ', f)
# Out:
# Aaron has friends:
#   Chris
#   Emma
#   Josh
#   Jess
# Chris has friends:
#   Aaron
#   Drew
#   Jane
#   Mike
#   Sarah
# Emma has friends:
#   Aaron
#   Josh
#   Sarah
# Josh has friends:
#   Aaron
#   Emma
#   Jess
#   Mike
# Drew has friends:
#   Chris
#   Sarah
# Jane has friends:
#   Chris
#   Sam
# Jess has friends:
#   Aaron
#   Josh
#   Mike
# Mike has friends:
#   Chris
#   Josh
#   Jess
# Sarah has friends:
#   Drew
#   Chris
#   Emma
# Sam has friends:
#   Jane

# %%
# Friends lists v2
for n in G:
    print(n, 'has friends:', list(G.neighbors(n)))
# Out:
# Aaron has friends: ['Chris', 'Emma', 'Josh', 'Jess']
# Chris has friends: ['Aaron', 'Drew', 'Jane', 'Mike', 'Sarah']
# Emma has friends: ['Aaron', 'Josh', 'Sarah']
# Josh has friends: ['Aaron', 'Emma', 'Jess', 'Mike']
# Drew has friends: ['Chris', 'Sarah']
# Jane has friends: ['Chris', 'Sam']
# Jess has friends: ['Aaron', 'Josh', 'Mike']
# Mike has friends: ['Chris', 'Josh', 'Jess']
# Sarah has friends: ['Drew', 'Chris', 'Emma']
# Sam has friends: ['Jane']

# %%
# Closeness centrality - average shortest distance to other nodes, normalized on reverse 0-1 scale
cc = nx.closeness_centrality(G)
print(cc)
# sorted_keys = sorted(cc, key=cc.get, reverse=True)
# print(sorted_keys)
# for k in sorted_keys:
#    print(k, 'has closeness centrality', cc[k])
# Out:
# {'Aaron': 0.6, 'Chris': 0.6923076923076923, 'Emma': 0.5, 'Josh': 0.5, 'Drew': 0.47368421052631576, 'Jane': 0.47368421052631576, 'Jess': 0.45, 'Mike': 0.5625, 'Sarah': 0.5294117647058824, 'Sam': 0.3333333333333333}

# %%
# Betweenness centrality - number of shortest paths it's on, normalized on 0-1 scale
bc = nx.betweenness_centrality(G)
sorted_keys = sorted(bc, key=bc.get, reverse=True)
for k in sorted_keys:
    print(k, 'has betweenness centrality', bc[k])
# Out:
# Chris has betweenness centrality 0.5555555555555556
# Jane has betweenness centrality 0.2222222222222222
# Aaron has betweenness centrality 0.1759259259259259
# Mike has betweenness centrality 0.11342592592592592
# Sarah has betweenness centrality 0.0787037037037037
# Emma has betweenness centrality 0.0648148148148148
# Josh has betweenness centrality 0.05787037037037036
# Jess has betweenness centrality 0.009259259259259259
# Drew has betweenness centrality 0.0
# Sam has betweenness centrality 0.0

# %% [markdown]
# ### Directed graph (Followers)

# %%
# Load graph from CSV file with no header
f = open('Follows.csv')
D = nx.read_edgelist(f, delimiter=',', nodetype=str, create_using=nx.DiGraph())
print(D)
# Out:
# DiGraph with 10 nodes and 18 edges

# %%
# Display graph
plt.figure(figsize=(8,8))
plt.margins(x=0.1, y=0.1)
nx.draw(D, with_labels=True, node_size=1500, arrows=True, node_color='c')

# %%
# Number of follows and followers
follows = D.out_degree
followers = D.in_degree
print('Number of follows: ', follows)
print('Number of followers: ', followers)
# Can treat list of pairs like a dictionary
# for n in D:
#    print(n, 'follows', follows[n], 'and has', followers[n], 'followers')
# Out:
# Number of follows:  [('Aaron', 3), ('Chris', 2), ('Emma', 2), ('Josh', 0), ('Drew', 1), ('Mike', 3), ('Sarah', 2), ('Jane', 1), ('Jess', 2), ('Sam', 2)]
# Number of followers:  [('Aaron', 3), ('Chris', 4), ('Emma', 2), ('Josh', 3), ('Drew', 1), ('Mike', 2), ('Sarah', 1), ('Jane', 1), ('Jess', 1), ('Sam', 0)]

# %%
# Reciprocity - people that follow each other (see what's wrong and fix it)
for n in D:
    print(n, list(D.neighbors(n)))
#    for n2 in list(D.neighbors(n)):
#        if n in list(D.neighbors(n2)):
#            print(n, 'and', n2, 'follow each other')
# Out:
# Aaron ['Chris', 'Emma', 'Josh']
# Chris ['Aaron', 'Drew']
# Emma ['Josh', 'Sarah']
# Josh []
# Drew ['Mike']
# Mike ['Chris', 'Josh', 'Jess']
# Sarah ['Chris', 'Emma']
# Jane ['Chris']
# Jess ['Aaron', 'Mike']
# Sam ['Aaron', 'Jane']

# %%
# Cycles
cycles = nx.simple_cycles(D)
for c in cycles:
    print(c)
# Out:
# ['Emma', 'Sarah', 'Chris', 'Aaron']
# ['Emma', 'Sarah', 'Chris', 'Drew', 'Mike', 'Jess', 'Aaron']
# ['Emma', 'Sarah']
# ['Aaron', 'Chris']
# ['Aaron', 'Chris', 'Drew', 'Mike', 'Jess']
# ['Chris', 'Drew', 'Mike']
# ['Mike', 'Jess']

# %%
# Alternative reciprocity
cycles = nx.simple_cycles(D)
for c in cycles:
    if len(c) == 2:
        print(c[0], 'and', c[1], 'follow each other')
# Out:
# Emma and Sarah follow each other
# Aaron and Chris follow each other
# Mike and Jess follow each other

# %% [markdown]
# ### <font color="green">**Your Turn: Dolphins Data**</font>

# %%
# Load the dolphin friends data and print the graph
f = open('Dolphins.csv')
G = nx.read_edgelist(f, delimiter=',', nodetype=str)
print(G)
nx.draw(G, node_size=100)
# Out:
# Graph with 62 nodes and 159 edges

# %% [markdown]
# <b>Friendliest dolphin:</b><br><i>Find the dolphin with the most friends. Don't worry about ties - there's one who's the friendliest. Print the dolphin's identifier and the number of friends the dolphin has.</i>

# %%
# Reminder: G.degree returns a list with the number of edges incident on each node
# Hint: Iterate through the G.degree list keeping track of the dolphin with the most
# friends, and how many friends it has

max_friend_sum = 0
max_friend = ''
for n in G:
  friends = G.neighbors(n)
  friend_sum = 0
  for f in friends:
    friend_sum += 1
  #print(n, 'has', friend_sum, 'friends')

  if friend_sum > max_friend_sum:
    max_friend_sum = friend_sum
    max_friend = n

print('The friendliest dolphin is', max_friend, 'with', max_friend_sum, 'friends')
# Out:
# The friendliest dolphin is 15 with 12 friends

# %% [markdown]
# <b>Dolphin friend recommendation, a type of "link prediction":</b><br>
# <i>Find all pairs of dolphins who are not friends but have at least four friends in common. Print each pair only once, and include a list of the friends they have in common.</i>

# %%
# The following code finds the common friends of all pairs of dolphins in the graph
# (without eliminating self-pairs or reverse-pairs).
# You can use it as a starting point for solving the problem.
for n1 in G:
    for n2 in G:
        common = set(G.neighbors(n1)) & set(G.neighbors(n2)) # performs intersection of two lists
        print('Dolphins', n1, 'and', n2, 'have friends', list(common), 'in common')
# Out:
# Dolphins 4 and 4 have friends ['60', '9', '15'] in common
# Dolphins 4 and 9 have friends ['60'] in common
# Dolphins 4 and 6 have friends [] in common
# Dolphins 4 and 10 have friends [] in common
# Dolphins 4 and 7 have friends [] in common
# Dolphins 4 and 1 have friends ['15'] in common
# Dolphins 4 and 11 have friends [] in common
# Dolphins 4 and 3 have friends [] in common
# Dolphins 4 and 14 have friends [] in common
# Dolphins 4 and 15 have friends [] in common
# Dolphins 4 and 16 have friends ['60'] in common
# Dolphins 4 and 17 have friends ['15'] in common
# Dolphins 4 and 2 have friends [] in common
# Dolphins 4 and 18 have friends [] in common
# Dolphins 4 and 19 have friends [] in common
# Dolphins 4 and 20 have friends [] in common
# Dolphins 4 and 8 have friends [] in common
# Dolphins 4 and 21 have friends ['9'] in common
# Dolphins 4 and 22 have friends [] in common
# Dolphins 4 and 23 have friends [] in common
# Dolphins 4 and 25 have friends ['15'] in common
# Dolphins 4 and 26 have friends [] in common
# Dolphins 4 and 27 have friends [] in common
# Dolphins 4 and 28 have friends [] in common
# Dolphins 4 and 29 have friends ['9'] in common
# Dolphins 4 and 30 have friends [] in common
# Dolphins 4 and 31 have friends [] in common
# Dolphins 4 and 32 have friends [] in common
# Dolphins 4 and 33 have friends [] in common
# Dolphins 4 and 13 have friends [] in common
# Dolphins 4 and 34 have friends ['15'] in common
# Dolphins 4 and 35 have friends ['15'] in common
# Dolphins 4 and 36 have friends [] in common
# Dolphins 4 and 37 have friends ['60'] in common
# Dolphins 4 and 24 have friends [] in common
# Dolphins 4 and 38 have friends ['9', '15'] in common
# Dolphins 4 and 39 have friends ['15'] in common
# Dolphins 4 and 40 have friends [] in common
# Dolphins 4 and 41 have friends ['15'] in common
# Dolphins 4 and 42 have friends [] in common
# Dolphins 4 and 43 have friends [] in common
# Dolphins 4 and 44 have friends ['15'] in common
# Dolphins 4 and 45 have friends [] in common
# Dolphins 4 and 46 have friends ['60', '9'] in common
# Dolphins 4 and 47 have friends [] in common
# Dolphins 4 and 48 have friends [] in common
# Dolphins 4 and 50 have friends [] in common
# Dolphins 4 and 51 have friends ['15'] in common
# Dolphins 4 and 5 have friends [] in common
# Dolphins 4 and 52 have friends [] in common
# Dolphins 4 and 12 have friends [] in common
# Dolphins 4 and 53 have friends ['15'] in common
# Dolphins 4 and 54 have friends [] in common
# Dolphins 4 and 55 have friends [] in common
# Dolphins 4 and 56 have friends [] in common
# Dolphins 4 and 57 have friends [] in common
# Dolphins 4 and 58 have friends [] in common
# Dolphins 4 and 49 have friends [] in common
# Dolphins 4 and 59 have friends [] in common
# Dolphins 4 and 60 have friends ['9'] in common
# Dolphins 4 and 61 have friends [] in common
# Dolphins 4 and 62 have friends [] in common
# Dolphins 9 and 4 have friends ['60'] in common
# Dolphins 9 and 9 have friends ['4', '60', '29', '21', '38', '46'] in common
# Dolphins 9 and 6 have friends [] in common
# Dolphins 9 and 10 have friends [] in common
# Dolphins 9 and 7 have friends [] in common
# Dolphins 9 and 1 have friends [] in common
# Dolphins 9 and 11 have friends [] in common
# Dolphins 9 and 3 have friends [] in common
# Dolphins 9 and 14 have friends [] in common
# Dolphins 9 and 15 have friends ['38', '4'] in common
# Dolphins 9 and 16 have friends ['46', '60'] in common
# Dolphins 9 and 17 have friends ['38', '21'] in common
# Dolphins 9 and 2 have friends ['29'] in common
# Dolphins 9 and 18 have friends [] in common
# Dolphins 9 and 19 have friends ['46', '21'] in common
# Dolphins 9 and 20 have friends [] in common
# Dolphins 9 and 8 have friends [] in common
# Dolphins 9 and 21 have friends ['29'] in common
# Dolphins 9 and 22 have friends ['38', '46'] in common
# Dolphins 9 and 23 have friends [] in common
# Dolphins 9 and 25 have friends ['46'] in common
# Dolphins 9 and 26 have friends [] in common
# Dolphins 9 and 27 have friends [] in common
# Dolphins 9 and 28 have friends [] in common
# Dolphins 9 and 29 have friends ['21'] in common
# Dolphins 9 and 30 have friends ['46'] in common
# Dolphins 9 and 31 have friends ['29'] in common
# Dolphins 9 and 32 have friends [] in common
# Dolphins 9 and 33 have friends [] in common
# Dolphins 9 and 13 have friends [] in common
# Dolphins 9 and 34 have friends ['38'] in common
# Dolphins 9 and 35 have friends ['38'] in common
# Dolphins 9 and 36 have friends [] in common
# Dolphins 9 and 37 have friends ['38', '60', '21'] in common
# Dolphins 9 and 24 have friends ['46'] in common
# Dolphins 9 and 38 have friends ['46'] in common
# Dolphins 9 and 39 have friends ['21'] in common
# Dolphins 9 and 40 have friends [] in common
# Dolphins 9 and 41 have friends ['38'] in common
# Dolphins 9 and 42 have friends [] in common
# Dolphins 9 and 43 have friends [] in common
# Dolphins 9 and 44 have friends ['38'] in common
# Dolphins 9 and 45 have friends ['21'] in common
# Dolphins 9 and 46 have friends ['38', '60'] in common
# Dolphins 9 and 47 have friends [] in common
# Dolphins 9 and 48 have friends ['29', '21'] in common
# Dolphins 9 and 50 have friends [] in common
# Dolphins 9 and 51 have friends ['46', '21'] in common
# Dolphins 9 and 5 have friends [] in common
# Dolphins 9 and 52 have friends ['46'] in common
# Dolphins 9 and 12 have friends [] in common
# Dolphins 9 and 53 have friends [] in common
# Dolphins 9 and 54 have friends [] in common
# Dolphins 9 and 55 have friends [] in common
# Dolphins 9 and 56 have friends [] in common
# Dolphins 9 and 57 have friends [] in common
# Dolphins 9 and 58 have friends [] in common
# Dolphins 9 and 49 have friends [] in common
# Dolphins 9 and 59 have friends [] in common
# Dolphins 9 and 60 have friends ['46', '4'] in common
# Dolphins 9 and 61 have friends [] in common
# Dolphins 9 and 62 have friends ['38'] in common
# Dolphins 6 and 4 have friends [] in common
# Dolphins 6 and 9 have friends [] in common
# Dolphins 6 and 6 have friends ['10', '58', '14', '57'] in common
# Dolphins 6 and 10 have friends ['58', '14'] in common
# Dolphins 6 and 7 have friends ['10', '58', '14', '57'] in common
# Dolphins 6 and 1 have friends [] in common
# Dolphins 6 and 11 have friends [] in common
# Dolphins 6 and 3 have friends [] in common
# Dolphins 6 and 14 have friends ['10', '58'] in common
# Dolphins 6 and 15 have friends [] in common
# Dolphins 6 and 16 have friends [] in common
# Dolphins 6 and 17 have friends [] in common
# Dolphins 6 and 2 have friends [] in common
# Dolphins 6 and 18 have friends ['10', '58', '14'] in common
# Dolphins 6 and 19 have friends [] in common
# Dolphins 6 and 20 have friends [] in common
# Dolphins 6 and 8 have friends [] in common
# Dolphins 6 and 21 have friends [] in common
# Dolphins 6 and 22 have friends [] in common
# Dolphins 6 and 23 have friends [] in common
# Dolphins 6 and 25 have friends [] in common
# Dolphins 6 and 26 have friends [] in common
# Dolphins 6 and 27 have friends [] in common
# Dolphins 6 and 28 have friends [] in common
# Dolphins 6 and 29 have friends [] in common
# Dolphins 6 and 30 have friends [] in common
# Dolphins 6 and 31 have friends [] in common
# Dolphins 6 and 32 have friends [] in common
# Dolphins 6 and 33 have friends ['10', '14'] in common
# Dolphins 6 and 13 have friends [] in common
# Dolphins 6 and 34 have friends [] in common
# Dolphins 6 and 35 have friends [] in common
# Dolphins 6 and 36 have friends [] in common
# Dolphins 6 and 37 have friends [] in common
# Dolphins 6 and 24 have friends [] in common
# Dolphins 6 and 38 have friends [] in common
# Dolphins 6 and 39 have friends [] in common
# Dolphins 6 and 40 have friends ['58'] in common
# Dolphins 6 and 41 have friends [] in common
# Dolphins 6 and 42 have friends ['10', '58', '14'] in common
# Dolphins 6 and 43 have friends [] in common
# Dolphins 6 and 44 have friends [] in common
# Dolphins 6 and 45 have friends [] in common
# Dolphins 6 and 46 have friends [] in common
# Dolphins 6 and 47 have friends [] in common
# Dolphins 6 and 48 have friends [] in common
# Dolphins 6 and 50 have friends [] in common
# Dolphins 6 and 51 have friends [] in common
# Dolphins 6 and 5 have friends [] in common
# Dolphins 6 and 52 have friends [] in common
# Dolphins 6 and 12 have friends [] in common
# Dolphins 6 and 53 have friends [] in common
# Dolphins 6 and 54 have friends [] in common
# Dolphins 6 and 55 have friends ['58', '14'] in common
# Dolphins 6 and 56 have friends [] in common
# Dolphins 6 and 57 have friends [] in common
# Dolphins 6 and 58 have friends ['10', '14'] in common
# Dolphins 6 and 49 have friends ['58'] in common
# Dolphins 6 and 59 have friends [] in common
# Dolphins 6 and 60 have friends [] in common
# Dolphins 6 and 61 have friends [] in common
# Dolphins 6 and 62 have friends [] in common
# Dolphins 10 and 4 have friends [] in common
# Dolphins 10 and 9 have friends [] in common
# Dolphins 10 and 6 have friends ['58', '14'] in common
# Dolphins 10 and 10 have friends ['58', '14', '18', '6', '33', '42', '7'] in common
# Dolphins 10 and 7 have friends ['58', '14', '18'] in common
# Dolphins 10 and 1 have friends [] in common
# Dolphins 10 and 11 have friends [] in common
# Dolphins 10 and 3 have friends [] in common
# Dolphins 10 and 14 have friends ['58', '18', '6', '33', '42', '7'] in common
# Dolphins 10 and 15 have friends [] in common
# Dolphins 10 and 16 have friends [] in common
# Dolphins 10 and 17 have friends [] in common
# Dolphins 10 and 2 have friends ['18', '42'] in common
# Dolphins 10 and 18 have friends ['58', '14', '7'] in common
# Dolphins 10 and 19 have friends [] in common
# Dolphins 10 and 20 have friends [] in common
# Dolphins 10 and 8 have friends [] in common
# Dolphins 10 and 21 have friends [] in common
# Dolphins 10 and 22 have friends [] in common
# Dolphins 10 and 23 have friends ['18'] in common
# Dolphins 10 and 25 have friends [] in common
# Dolphins 10 and 26 have friends ['18'] in common
# Dolphins 10 and 27 have friends [] in common
# Dolphins 10 and 28 have friends ['18'] in common
# Dolphins 10 and 29 have friends [] in common
# Dolphins 10 and 30 have friends [] in common
# Dolphins 10 and 31 have friends [] in common
# Dolphins 10 and 32 have friends ['18'] in common
# Dolphins 10 and 33 have friends ['14'] in common
# Dolphins 10 and 13 have friends [] in common
# Dolphins 10 and 34 have friends [] in common
# Dolphins 10 and 35 have friends [] in common
# Dolphins 10 and 36 have friends [] in common
# Dolphins 10 and 37 have friends [] in common
# Dolphins 10 and 24 have friends [] in common
# Dolphins 10 and 38 have friends [] in common
# Dolphins 10 and 39 have friends [] in common
# Dolphins 10 and 40 have friends ['58'] in common
# Dolphins 10 and 41 have friends [] in common
# Dolphins 10 and 42 have friends ['58', '14'] in common
# Dolphins 10 and 43 have friends [] in common
# Dolphins 10 and 44 have friends [] in common
# Dolphins 10 and 45 have friends [] in common
# Dolphins 10 and 46 have friends [] in common
# Dolphins 10 and 47 have friends [] in common
# Dolphins 10 and 48 have friends [] in common
# Dolphins 10 and 50 have friends [] in common
# Dolphins 10 and 51 have friends [] in common
# Dolphins 10 and 5 have friends [] in common
# Dolphins 10 and 52 have friends [] in common
# Dolphins 10 and 12 have friends [] in common
# Dolphins 10 and 53 have friends [] in common
# Dolphins 10 and 54 have friends [] in common
# Dolphins 10 and 55 have friends ['58', '14', '7', '42'] in common
# Dolphins 10 and 56 have friends [] in common
# Dolphins 10 and 57 have friends ['6', '7'] in common
# Dolphins 10 and 58 have friends ['14', '18', '6', '42', '7'] in common
# Dolphins 10 and 49 have friends ['58'] in common
# Dolphins 10 and 59 have friends [] in common
# Dolphins 10 and 60 have friends [] in common
# Dolphins 10 and 61 have friends ['33'] in common
# Dolphins 10 and 62 have friends [] in common
# Dolphins 7 and 4 have friends [] in common
# Dolphins 7 and 9 have friends [] in common
# Dolphins 7 and 6 have friends ['10', '58', '14', '57'] in common
# Dolphins 7 and 10 have friends ['58', '14', '18'] in common
# Dolphins 7 and 7 have friends ['58', '14', '55', '10', '18', '57'] in common
# Dolphins 7 and 1 have friends [] in common
# Dolphins 7 and 11 have friends [] in common
# Dolphins 7 and 3 have friends [] in common
# Dolphins 7 and 14 have friends ['10', '58', '18', '55'] in common
# Dolphins 7 and 15 have friends [] in common
# Dolphins 7 and 16 have friends [] in common
# Dolphins 7 and 17 have friends [] in common
# Dolphins 7 and 2 have friends ['18', '55'] in common
# Dolphins 7 and 18 have friends ['10', '58', '14'] in common
# Dolphins 7 and 19 have friends [] in common
# Dolphins 7 and 20 have friends ['55'] in common
# Dolphins 7 and 8 have friends ['55'] in common
# Dolphins 7 and 21 have friends [] in common
# Dolphins 7 and 22 have friends [] in common
# Dolphins 7 and 23 have friends ['18'] in common
# Dolphins 7 and 25 have friends [] in common
# Dolphins 7 and 26 have friends ['18'] in common
# Dolphins 7 and 27 have friends [] in common
# Dolphins 7 and 28 have friends ['18'] in common
# Dolphins 7 and 29 have friends [] in common
# Dolphins 7 and 30 have friends [] in common
# Dolphins 7 and 31 have friends [] in common
# Dolphins 7 and 32 have friends ['18'] in common
# Dolphins 7 and 33 have friends ['10', '14'] in common
# Dolphins 7 and 13 have friends [] in common
# Dolphins 7 and 34 have friends [] in common
# Dolphins 7 and 35 have friends [] in common
# Dolphins 7 and 36 have friends [] in common
# Dolphins 7 and 37 have friends [] in common
# Dolphins 7 and 24 have friends [] in common
# Dolphins 7 and 38 have friends [] in common
# Dolphins 7 and 39 have friends [] in common
# Dolphins 7 and 40 have friends ['58'] in common
# Dolphins 7 and 41 have friends [] in common
# Dolphins 7 and 42 have friends ['10', '58', '14', '55'] in common
# Dolphins 7 and 43 have friends [] in common
# Dolphins 7 and 44 have friends [] in common
# Dolphins 7 and 45 have friends [] in common
# Dolphins 7 and 46 have friends [] in common
# Dolphins 7 and 47 have friends [] in common
# Dolphins 7 and 48 have friends [] in common
# Dolphins 7 and 50 have friends [] in common
# Dolphins 7 and 51 have friends [] in common
# Dolphins 7 and 5 have friends [] in common
# Dolphins 7 and 52 have friends [] in common
# Dolphins 7 and 12 have friends [] in common
# Dolphins 7 and 53 have friends [] in common
# Dolphins 7 and 54 have friends [] in common
# Dolphins 7 and 55 have friends ['58', '14'] in common
# Dolphins 7 and 56 have friends [] in common
# Dolphins 7 and 57 have friends [] in common
# Dolphins 7 and 58 have friends ['10', '18', '14', '55'] in common
# Dolphins 7 and 49 have friends ['58'] in common
# Dolphins 7 and 59 have friends [] in common
# Dolphins 7 and 60 have friends [] in common
# Dolphins 7 and 61 have friends [] in common
# Dolphins 7 and 62 have friends [] in common
# Dolphins 1 and 4 have friends ['15'] in common
# Dolphins 1 and 9 have friends [] in common
# Dolphins 1 and 6 have friends [] in common
# Dolphins 1 and 10 have friends [] in common
# Dolphins 1 and 7 have friends [] in common
# Dolphins 1 and 1 have friends ['48', '41', '16', '15', '43', '11'] in common
# Dolphins 1 and 11 have friends ['48', '43'] in common
# Dolphins 1 and 3 have friends ['43', '11'] in common
# Dolphins 1 and 14 have friends [] in common
# Dolphins 1 and 15 have friends ['41'] in common
# Dolphins 1 and 16 have friends ['41'] in common
# Dolphins 1 and 17 have friends ['15'] in common
# Dolphins 1 and 2 have friends [] in common
# Dolphins 1 and 18 have friends [] in common
# Dolphins 1 and 19 have friends ['16'] in common
# Dolphins 1 and 20 have friends [] in common
# Dolphins 1 and 8 have friends ['41'] in common
# Dolphins 1 and 21 have friends ['48'] in common
# Dolphins 1 and 22 have friends [] in common
# Dolphins 1 and 23 have friends [] in common
# Dolphins 1 and 25 have friends ['16', '15'] in common
# Dolphins 1 and 26 have friends [] in common
# Dolphins 1 and 27 have friends [] in common
# Dolphins 1 and 28 have friends [] in common
# Dolphins 1 and 29 have friends ['48'] in common
# Dolphins 1 and 30 have friends ['11'] in common
# Dolphins 1 and 31 have friends ['48', '43'] in common
# Dolphins 1 and 32 have friends [] in common
# Dolphins 1 and 33 have friends [] in common
# Dolphins 1 and 13 have friends [] in common
# Dolphins 1 and 34 have friends ['41', '15'] in common
# Dolphins 1 and 35 have friends ['15'] in common
# Dolphins 1 and 36 have friends [] in common
# Dolphins 1 and 37 have friends ['41'] in common
# Dolphins 1 and 24 have friends [] in common
# Dolphins 1 and 38 have friends ['41', '15'] in common
# Dolphins 1 and 39 have friends ['15'] in common
# Dolphins 1 and 40 have friends [] in common
# Dolphins 1 and 41 have friends ['16', '15'] in common
# Dolphins 1 and 42 have friends [] in common
# Dolphins 1 and 43 have friends ['48', '11'] in common
# Dolphins 1 and 44 have friends ['15'] in common
# Dolphins 1 and 45 have friends [] in common
# Dolphins 1 and 46 have friends ['16'] in common
# Dolphins 1 and 47 have friends [] in common
# Dolphins 1 and 48 have friends ['43', '11'] in common
# Dolphins 1 and 50 have friends [] in common
# Dolphins 1 and 51 have friends ['43', '15'] in common
# Dolphins 1 and 5 have friends [] in common
# Dolphins 1 and 52 have friends [] in common
# Dolphins 1 and 12 have friends [] in common
# Dolphins 1 and 53 have friends ['41', '15'] in common
# Dolphins 1 and 54 have friends [] in common
# Dolphins 1 and 55 have friends [] in common
# Dolphins 1 and 56 have friends ['16'] in common
# Dolphins 1 and 57 have friends [] in common
# Dolphins 1 and 58 have friends [] in common
# Dolphins 1 and 49 have friends [] in common
# Dolphins 1 and 59 have friends [] in common
# Dolphins 1 and 60 have friends ['16'] in common
# Dolphins 1 and 61 have friends [] in common
# Dolphins 1 and 62 have friends [] in common
# Dolphins 11 and 4 have friends [] in common
# Dolphins 11 and 9 have friends [] in common
# Dolphins 11 and 6 have friends [] in common
# Dolphins 11 and 10 have friends [] in common
# Dolphins 11 and 7 have friends [] in common
# Dolphins 11 and 1 have friends ['48', '43'] in common
# Dolphins 11 and 11 have friends ['3', '48', '1', '30', '43'] in common
# Dolphins 11 and 3 have friends ['43'] in common
# Dolphins 11 and 14 have friends [] in common
# Dolphins 11 and 15 have friends ['1'] in common
# Dolphins 11 and 16 have friends ['1'] in common
# Dolphins 11 and 17 have friends [] in common
# Dolphins 11 and 2 have friends [] in common
# Dolphins 11 and 18 have friends [] in common
# Dolphins 11 and 19 have friends ['30'] in common
# Dolphins 11 and 20 have friends [] in common
# Dolphins 11 and 8 have friends [] in common
# Dolphins 11 and 21 have friends ['48'] in common
# Dolphins 11 and 22 have friends ['30'] in common
# Dolphins 11 and 23 have friends [] in common
# Dolphins 11 and 25 have friends ['30'] in common
# Dolphins 11 and 26 have friends [] in common
# Dolphins 11 and 27 have friends [] in common
# Dolphins 11 and 28 have friends [] in common
# Dolphins 11 and 29 have friends ['48'] in common
# Dolphins 11 and 30 have friends [] in common
# Dolphins 11 and 31 have friends ['48', '43'] in common
# Dolphins 11 and 32 have friends [] in common
# Dolphins 11 and 33 have friends [] in common
# Dolphins 11 and 13 have friends [] in common
# Dolphins 11 and 34 have friends [] in common
# Dolphins 11 and 35 have friends [] in common
# Dolphins 11 and 36 have friends ['30'] in common
# Dolphins 11 and 37 have friends [] in common
# Dolphins 11 and 24 have friends [] in common
# Dolphins 11 and 38 have friends [] in common
# Dolphins 11 and 39 have friends [] in common
# Dolphins 11 and 40 have friends [] in common
# Dolphins 11 and 41 have friends ['1'] in common
# Dolphins 11 and 42 have friends [] in common
# Dolphins 11 and 43 have friends ['3', '48', '1'] in common
# Dolphins 11 and 44 have friends ['30'] in common
# Dolphins 11 and 45 have friends ['3'] in common
# Dolphins 11 and 46 have friends ['30'] in common
# Dolphins 11 and 47 have friends [] in common
# Dolphins 11 and 48 have friends ['1', '43'] in common
# Dolphins 11 and 50 have friends [] in common
# Dolphins 11 and 51 have friends ['43'] in common
# Dolphins 11 and 5 have friends [] in common
# Dolphins 11 and 52 have friends ['30'] in common
# Dolphins 11 and 12 have friends [] in common
# Dolphins 11 and 53 have friends ['30'] in common
# Dolphins 11 and 54 have friends [] in common
# Dolphins 11 and 55 have friends [] in common
# Dolphins 11 and 56 have friends [] in common
# Dolphins 11 and 57 have friends [] in common
# Dolphins 11 and 58 have friends [] in common
# Dolphins 11 and 49 have friends [] in common
# Dolphins 11 and 59 have friends [] in common
# Dolphins 11 and 60 have friends [] in common
# Dolphins 11 and 61 have friends [] in common
# Dolphins 11 and 62 have friends ['3'] in common
# Dolphins 3 and 4 have friends [] in common
# Dolphins 3 and 9 have friends [] in common
# Dolphins 3 and 6 have friends [] in common
# Dolphins 3 and 10 have friends [] in common
# Dolphins 3 and 7 have friends [] in common
# Dolphins 3 and 1 have friends ['43', '11'] in common
# Dolphins 3 and 11 have friends ['43'] in common
# Dolphins 3 and 3 have friends ['11', '62', '43', '45'] in common
# Dolphins 3 and 14 have friends [] in common
# Dolphins 3 and 15 have friends [] in common
# Dolphins 3 and 16 have friends [] in common
# Dolphins 3 and 17 have friends [] in common
# Dolphins 3 and 2 have friends [] in common
# Dolphins 3 and 18 have friends [] in common
# Dolphins 3 and 19 have friends [] in common
# Dolphins 3 and 20 have friends [] in common
# Dolphins 3 and 8 have friends [] in common
# Dolphins 3 and 21 have friends ['45'] in common
# Dolphins 3 and 22 have friends [] in common
# Dolphins 3 and 23 have friends [] in common
# Dolphins 3 and 25 have friends [] in common
# Dolphins 3 and 26 have friends [] in common
# Dolphins 3 and 27 have friends [] in common
# Dolphins 3 and 28 have friends [] in common
# Dolphins 3 and 29 have friends [] in common
# Dolphins 3 and 30 have friends ['11'] in common
# Dolphins 3 and 31 have friends ['43'] in common
# Dolphins 3 and 32 have friends [] in common
# Dolphins 3 and 33 have friends [] in common
# Dolphins 3 and 13 have friends [] in common
# Dolphins 3 and 34 have friends [] in common
# Dolphins 3 and 35 have friends ['45'] in common
# Dolphins 3 and 36 have friends [] in common
# Dolphins 3 and 37 have friends [] in common
# Dolphins 3 and 24 have friends [] in common
# Dolphins 3 and 38 have friends ['62'] in common
# Dolphins 3 and 39 have friends ['45'] in common
# Dolphins 3 and 40 have friends [] in common
# Dolphins 3 and 41 have friends [] in common
# Dolphins 3 and 42 have friends [] in common
# Dolphins 3 and 43 have friends ['11'] in common
# Dolphins 3 and 44 have friends [] in common
# Dolphins 3 and 45 have friends [] in common
# Dolphins 3 and 46 have friends [] in common
# Dolphins 3 and 47 have friends [] in common
# Dolphins 3 and 48 have friends ['43', '11'] in common
# Dolphins 3 and 50 have friends [] in common
# Dolphins 3 and 51 have friends ['43'] in common
# Dolphins 3 and 5 have friends [] in common
# Dolphins 3 and 52 have friends [] in common
# Dolphins 3 and 12 have friends [] in common
# Dolphins 3 and 53 have friends [] in common
# Dolphins 3 and 54 have friends ['62'] in common
# Dolphins 3 and 55 have friends [] in common
# Dolphins 3 and 56 have friends [] in common
# Dolphins 3 and 57 have friends [] in common
# Dolphins 3 and 58 have friends [] in common
# Dolphins 3 and 49 have friends [] in common
# Dolphins 3 and 59 have friends [] in common
# Dolphins 3 and 60 have friends [] in common
# Dolphins 3 and 61 have friends [] in common
# Dolphins 3 and 62 have friends [] in common
# Dolphins 14 and 4 have friends [] in common
# Dolphins 14 and 9 have friends [] in common
# Dolphins 14 and 6 have friends ['10', '58'] in common
# Dolphins 14 and 10 have friends ['58', '18', '6', '33', '42', '7'] in common
# Dolphins 14 and 7 have friends ['10', '58', '18', '55'] in common
# Dolphins 14 and 1 have friends [] in common
# Dolphins 14 and 11 have friends [] in common
# Dolphins 14 and 3 have friends [] in common
# Dolphins 14 and 14 have friends ['58', '55', '10', '18', '6', '33', '42', '7'] in common
# Dolphins 14 and 15 have friends [] in common
# Dolphins 14 and 16 have friends [] in common
# Dolphins 14 and 17 have friends [] in common
# Dolphins 14 and 2 have friends ['18', '42', '55'] in common
# Dolphins 14 and 18 have friends ['10', '58', '7'] in common
# Dolphins 14 and 19 have friends [] in common
# Dolphins 14 and 20 have friends ['55'] in common
# Dolphins 14 and 8 have friends ['55'] in common
# Dolphins 14 and 21 have friends [] in common
# Dolphins 14 and 22 have friends [] in common
# Dolphins 14 and 23 have friends ['18'] in common
# Dolphins 14 and 25 have friends [] in common
# Dolphins 14 and 26 have friends ['18'] in common
# Dolphins 14 and 27 have friends [] in common
# Dolphins 14 and 28 have friends ['18'] in common
# Dolphins 14 and 29 have friends [] in common
# Dolphins 14 and 30 have friends [] in common
# Dolphins 14 and 31 have friends [] in common
# Dolphins 14 and 32 have friends ['18'] in common
# Dolphins 14 and 33 have friends ['10'] in common
# Dolphins 14 and 13 have friends [] in common
# Dolphins 14 and 34 have friends [] in common
# Dolphins 14 and 35 have friends [] in common
# Dolphins 14 and 36 have friends [] in common
# Dolphins 14 and 37 have friends [] in common
# Dolphins 14 and 24 have friends [] in common
# Dolphins 14 and 38 have friends [] in common
# Dolphins 14 and 39 have friends [] in common
# Dolphins 14 and 40 have friends ['58'] in common
# Dolphins 14 and 41 have friends [] in common
# Dolphins 14 and 42 have friends ['10', '58', '55'] in common
# Dolphins 14 and 43 have friends [] in common
# Dolphins 14 and 44 have friends [] in common
# Dolphins 14 and 45 have friends [] in common
# Dolphins 14 and 46 have friends [] in common
# Dolphins 14 and 47 have friends [] in common
# Dolphins 14 and 48 have friends [] in common
# Dolphins 14 and 50 have friends [] in common
# Dolphins 14 and 51 have friends [] in common
# Dolphins 14 and 5 have friends [] in common
# Dolphins 14 and 52 have friends [] in common
# Dolphins 14 and 12 have friends [] in common
# Dolphins 14 and 53 have friends [] in common
# Dolphins 14 and 54 have friends [] in common
# Dolphins 14 and 55 have friends ['58', '42', '7'] in common
# Dolphins 14 and 56 have friends [] in common
# Dolphins 14 and 57 have friends ['6', '7'] in common
# Dolphins 14 and 58 have friends ['55', '10', '18', '6', '42', '7'] in common
# Dolphins 14 and 49 have friends ['58'] in common
# Dolphins 14 and 59 have friends [] in common
# Dolphins 14 and 60 have friends [] in common
# Dolphins 14 and 61 have friends ['33'] in common
# Dolphins 14 and 62 have friends [] in common
# Dolphins 15 and 4 have friends [] in common
# Dolphins 15 and 9 have friends ['38', '4'] in common
# Dolphins 15 and 6 have friends [] in common
# Dolphins 15 and 10 have friends [] in common
# Dolphins 15 and 7 have friends [] in common
# Dolphins 15 and 1 have friends ['41'] in common
# Dolphins 15 and 11 have friends ['1'] in common
# Dolphins 15 and 3 have friends [] in common
# Dolphins 15 and 14 have friends [] in common
# Dolphins 15 and 15 have friends ['51', '4', '1', '53', '34', '17', '44', '35', '25', '41', '38', '39'] in common
# Dolphins 15 and 16 have friends ['25', '1', '41'] in common
# Dolphins 15 and 17 have friends ['51', '38', '34', '39'] in common
# Dolphins 15 and 2 have friends [] in common
# Dolphins 15 and 18 have friends [] in common
# Dolphins 15 and 19 have friends ['25'] in common
# Dolphins 15 and 20 have friends [] in common
# Dolphins 15 and 8 have friends ['41'] in common
# Dolphins 15 and 21 have friends ['51', '17', '39'] in common
# Dolphins 15 and 22 have friends ['38', '34'] in common
# Dolphins 15 and 23 have friends [] in common
# Dolphins 15 and 25 have friends [] in common
# Dolphins 15 and 26 have friends [] in common
# Dolphins 15 and 27 have friends [] in common
# Dolphins 15 and 28 have friends [] in common
# Dolphins 15 and 29 have friends [] in common
# Dolphins 15 and 30 have friends ['25', '53', '44'] in common
# Dolphins 15 and 31 have friends [] in common
# Dolphins 15 and 32 have friends [] in common
# Dolphins 15 and 33 have friends [] in common
# Dolphins 15 and 13 have friends ['34'] in common
# Dolphins 15 and 34 have friends ['51', '17', '44', '35', '41', '38', '39'] in common
# Dolphins 15 and 35 have friends ['38', '34'] in common
# Dolphins 15 and 36 have friends [] in common
# Dolphins 15 and 37 have friends ['38', '41'] in common
# Dolphins 15 and 24 have friends [] in common
# Dolphins 15 and 38 have friends ['34', '44', '35', '41', '17'] in common
# Dolphins 15 and 39 have friends ['53', '34', '17', '44'] in common
# Dolphins 15 and 40 have friends [] in common
# Dolphins 15 and 41 have friends ['38', '1', '53', '34'] in common
# Dolphins 15 and 42 have friends [] in common
# Dolphins 15 and 43 have friends ['51', '1'] in common
# Dolphins 15 and 44 have friends ['38', '34', '39'] in common
# Dolphins 15 and 45 have friends ['35', '39'] in common
# Dolphins 15 and 46 have friends ['51', '38', '25'] in common
# Dolphins 15 and 47 have friends ['44'] in common
# Dolphins 15 and 48 have friends ['1'] in common
# Dolphins 15 and 50 have friends ['35'] in common
# Dolphins 15 and 51 have friends ['34', '17'] in common
# Dolphins 15 and 5 have friends [] in common
# Dolphins 15 and 52 have friends ['51', '25'] in common
# Dolphins 15 and 12 have friends [] in common
# Dolphins 15 and 53 have friends ['41', '39'] in common
# Dolphins 15 and 54 have friends ['44'] in common
# Dolphins 15 and 55 have friends [] in common
# Dolphins 15 and 56 have friends [] in common
# Dolphins 15 and 57 have friends [] in common
# Dolphins 15 and 58 have friends [] in common
# Dolphins 15 and 49 have friends [] in common
# Dolphins 15 and 59 have friends ['39'] in common
# Dolphins 15 and 60 have friends ['4'] in common
# Dolphins 15 and 61 have friends [] in common
# Dolphins 15 and 62 have friends ['38'] in common
# Dolphins 16 and 4 have friends ['60'] in common
# Dolphins 16 and 9 have friends ['46', '60'] in common
# Dolphins 16 and 6 have friends [] in common
# Dolphins 16 and 10 have friends [] in common
# Dolphins 16 and 7 have friends [] in common
# Dolphins 16 and 1 have friends ['41'] in common
# Dolphins 16 and 11 have friends ['1'] in common
# Dolphins 16 and 3 have friends [] in common
# Dolphins 16 and 14 have friends [] in common
# Dolphins 16 and 15 have friends ['25', '1', '41'] in common
# Dolphins 16 and 16 have friends ['1', '60', '25', '41', '46', '56', '19'] in common
# Dolphins 16 and 17 have friends [] in common
# Dolphins 16 and 2 have friends [] in common
# Dolphins 16 and 18 have friends [] in common
# Dolphins 16 and 19 have friends ['46', '25'] in common
# Dolphins 16 and 20 have friends [] in common
# Dolphins 16 and 8 have friends ['41'] in common
# Dolphins 16 and 21 have friends ['19'] in common
# Dolphins 16 and 22 have friends ['46', '19'] in common
# Dolphins 16 and 23 have friends [] in common
# Dolphins 16 and 25 have friends ['46', '19'] in common
# Dolphins 16 and 26 have friends [] in common
# Dolphins 16 and 27 have friends [] in common
# Dolphins 16 and 28 have friends [] in common
# Dolphins 16 and 29 have friends [] in common
# Dolphins 16 and 30 have friends ['46', '25', '19'] in common
# Dolphins 16 and 31 have friends [] in common
# Dolphins 16 and 32 have friends [] in common
# Dolphins 16 and 33 have friends [] in common
# Dolphins 16 and 13 have friends [] in common
# Dolphins 16 and 34 have friends ['41'] in common
# Dolphins 16 and 35 have friends [] in common
# Dolphins 16 and 36 have friends [] in common
# Dolphins 16 and 37 have friends ['60', '41'] in common
# Dolphins 16 and 24 have friends ['46'] in common
# Dolphins 16 and 38 have friends ['46', '41'] in common
# Dolphins 16 and 39 have friends [] in common
# Dolphins 16 and 40 have friends [] in common
# Dolphins 16 and 41 have friends ['1'] in common
# Dolphins 16 and 42 have friends [] in common
# Dolphins 16 and 43 have friends ['1'] in common
# Dolphins 16 and 44 have friends [] in common
# Dolphins 16 and 45 have friends [] in common
# Dolphins 16 and 46 have friends ['60', '25', '19'] in common
# Dolphins 16 and 47 have friends [] in common
# Dolphins 16 and 48 have friends ['1'] in common
# Dolphins 16 and 50 have friends [] in common
# Dolphins 16 and 51 have friends ['46'] in common
# Dolphins 16 and 5 have friends [] in common
# Dolphins 16 and 52 have friends ['46', '25', '56', '19'] in common
# Dolphins 16 and 12 have friends [] in common
# Dolphins 16 and 53 have friends ['41'] in common
# Dolphins 16 and 54 have friends [] in common
# Dolphins 16 and 55 have friends [] in common
# Dolphins 16 and 56 have friends [] in common
# Dolphins 16 and 57 have friends [] in common
# Dolphins 16 and 58 have friends [] in common
# Dolphins 16 and 49 have friends [] in common
# Dolphins 16 and 59 have friends [] in common
# Dolphins 16 and 60 have friends ['46'] in common
# Dolphins 16 and 61 have friends [] in common
# Dolphins 16 and 62 have friends [] in common
# Dolphins 17 and 4 have friends ['15'] in common
# Dolphins 17 and 9 have friends ['38', '21'] in common
# Dolphins 17 and 6 have friends [] in common
# Dolphins 17 and 10 have friends [] in common
# Dolphins 17 and 7 have friends [] in common
# Dolphins 17 and 1 have friends ['15'] in common
# Dolphins 17 and 11 have friends [] in common
# Dolphins 17 and 3 have friends [] in common
# Dolphins 17 and 14 have friends [] in common
# Dolphins 17 and 15 have friends ['51', '38', '34', '39'] in common
# Dolphins 17 and 16 have friends [] in common
# Dolphins 17 and 17 have friends ['51', '34', '21', '38', '39', '15'] in common
# Dolphins 17 and 2 have friends [] in common
# Dolphins 17 and 18 have friends [] in common
# Dolphins 17 and 19 have friends ['21'] in common
# Dolphins 17 and 20 have friends [] in common
# Dolphins 17 and 8 have friends [] in common
# Dolphins 17 and 21 have friends ['51', '39'] in common
# Dolphins 17 and 22 have friends ['38', '34'] in common
# Dolphins 17 and 23 have friends [] in common
# Dolphins 17 and 25 have friends ['15'] in common
# Dolphins 17 and 26 have friends [] in common
# Dolphins 17 and 27 have friends [] in common
# Dolphins 17 and 28 have friends [] in common
# Dolphins 17 and 29 have friends ['21'] in common
# Dolphins 17 and 30 have friends [] in common
# Dolphins 17 and 31 have friends [] in common
# Dolphins 17 and 32 have friends [] in common
# Dolphins 17 and 33 have friends [] in common
# Dolphins 17 and 13 have friends ['34'] in common
# Dolphins 17 and 34 have friends ['51', '38', '39', '15'] in common
# Dolphins 17 and 35 have friends ['38', '34', '15'] in common
# Dolphins 17 and 36 have friends [] in common
# Dolphins 17 and 37 have friends ['38', '21'] in common
# Dolphins 17 and 24 have friends [] in common
# Dolphins 17 and 38 have friends ['34', '15'] in common
# Dolphins 17 and 39 have friends ['34', '15', '21'] in common
# Dolphins 17 and 40 have friends [] in common
# Dolphins 17 and 41 have friends ['38', '34', '15'] in common
# Dolphins 17 and 42 have friends [] in common
# Dolphins 17 and 43 have friends ['51'] in common
# Dolphins 17 and 44 have friends ['38', '39', '34', '15'] in common
# Dolphins 17 and 45 have friends ['39', '21'] in common
# Dolphins 17 and 46 have friends ['51', '38'] in common
# Dolphins 17 and 47 have friends [] in common
# Dolphins 17 and 48 have friends ['21'] in common
# Dolphins 17 and 50 have friends [] in common
# Dolphins 17 and 51 have friends ['34', '15', '21'] in common
# Dolphins 17 and 5 have friends [] in common
# Dolphins 17 and 52 have friends ['51'] in common
# Dolphins 17 and 12 have friends [] in common
# Dolphins 17 and 53 have friends ['15', '39'] in common
# Dolphins 17 and 54 have friends [] in common
# Dolphins 17 and 55 have friends [] in common
# Dolphins 17 and 56 have friends [] in common
# Dolphins 17 and 57 have friends [] in common
# Dolphins 17 and 58 have friends [] in common
# Dolphins 17 and 49 have friends [] in common
# Dolphins 17 and 59 have friends ['39'] in common
# Dolphins 17 and 60 have friends [] in common
# Dolphins 17 and 61 have friends [] in common
# Dolphins 17 and 62 have friends ['38'] in common
# Dolphins 2 and 4 have friends [] in common
# Dolphins 2 and 9 have friends ['29'] in common
# Dolphins 2 and 6 have friends [] in common
# Dolphins 2 and 10 have friends ['18', '42'] in common
# Dolphins 2 and 7 have friends ['18', '55'] in common
# Dolphins 2 and 1 have friends [] in common
# Dolphins 2 and 11 have friends [] in common
# Dolphins 2 and 3 have friends [] in common
# Dolphins 2 and 14 have friends ['18', '42', '55'] in common
# Dolphins 2 and 15 have friends [] in common
# Dolphins 2 and 16 have friends [] in common
# Dolphins 2 and 17 have friends [] in common
# Dolphins 2 and 2 have friends ['55', '27', '18', '29', '28', '20', '37', '42'] in common
# Dolphins 2 and 18 have friends ['28'] in common
# Dolphins 2 and 19 have friends [] in common
# Dolphins 2 and 20 have friends ['55'] in common
# Dolphins 2 and 8 have friends ['20', '55', '28'] in common
# Dolphins 2 and 21 have friends ['37', '29'] in common
# Dolphins 2 and 22 have friends [] in common
# Dolphins 2 and 23 have friends ['18'] in common
# Dolphins 2 and 25 have friends [] in common
# Dolphins 2 and 26 have friends ['27', '18', '28'] in common
# Dolphins 2 and 27 have friends ['28'] in common
# Dolphins 2 and 28 have friends ['27', '18'] in common
# Dolphins 2 and 29 have friends [] in common
# Dolphins 2 and 30 have friends [] in common
# Dolphins 2 and 31 have friends ['20', '29'] in common
# Dolphins 2 and 32 have friends ['18'] in common
# Dolphins 2 and 33 have friends [] in common
# Dolphins 2 and 13 have friends [] in common
# Dolphins 2 and 34 have friends [] in common
# Dolphins 2 and 35 have friends [] in common
# Dolphins 2 and 36 have friends [] in common
# Dolphins 2 and 37 have friends [] in common
# Dolphins 2 and 24 have friends ['37'] in common
# Dolphins 2 and 38 have friends ['37'] in common
# Dolphins 2 and 39 have friends [] in common
# Dolphins 2 and 40 have friends ['37'] in common
# Dolphins 2 and 41 have friends ['37'] in common
# Dolphins 2 and 42 have friends ['55'] in common
# Dolphins 2 and 43 have friends [] in common
# Dolphins 2 and 44 have friends [] in common
# Dolphins 2 and 45 have friends [] in common
# Dolphins 2 and 46 have friends [] in common
# Dolphins 2 and 47 have friends [] in common
# Dolphins 2 and 48 have friends ['29'] in common
# Dolphins 2 and 50 have friends [] in common
# Dolphins 2 and 51 have friends [] in common
# Dolphins 2 and 5 have friends [] in common
# Dolphins 2 and 52 have friends [] in common
# Dolphins 2 and 12 have friends [] in common
# Dolphins 2 and 53 have friends [] in common
# Dolphins 2 and 54 have friends [] in common
# Dolphins 2 and 55 have friends ['20', '42'] in common
# Dolphins 2 and 56 have friends [] in common
# Dolphins 2 and 57 have friends [] in common
# Dolphins 2 and 58 have friends ['18', '42', '55'] in common
# Dolphins 2 and 49 have friends [] in common
# Dolphins 2 and 59 have friends [] in common
# Dolphins 2 and 60 have friends ['37'] in common
# Dolphins 2 and 61 have friends [] in common
# Dolphins 2 and 62 have friends [] in common
# Dolphins 18 and 4 have friends [] in common
# Dolphins 18 and 9 have friends [] in common
# Dolphins 18 and 6 have friends ['10', '58', '14'] in common
# Dolphins 18 and 10 have friends ['58', '14', '7'] in common
# Dolphins 18 and 7 have friends ['10', '58', '14'] in common
# Dolphins 18 and 1 have friends [] in common
# Dolphins 18 and 11 have friends [] in common
# Dolphins 18 and 3 have friends [] in common
# Dolphins 18 and 14 have friends ['10', '58', '7'] in common
# Dolphins 18 and 15 have friends [] in common
# Dolphins 18 and 16 have friends [] in common
# Dolphins 18 and 17 have friends [] in common
# Dolphins 18 and 2 have friends ['28'] in common
# Dolphins 18 and 18 have friends ['23', '58', '14', '10', '26', '28', '32', '2', '7'] in common
# Dolphins 18 and 19 have friends [] in common
# Dolphins 18 and 20 have friends ['2'] in common
# Dolphins 18 and 8 have friends ['28'] in common
# Dolphins 18 and 21 have friends [] in common
# Dolphins 18 and 22 have friends [] in common
# Dolphins 18 and 23 have friends [] in common
# Dolphins 18 and 25 have friends [] in common
# Dolphins 18 and 26 have friends ['28'] in common
# Dolphins 18 and 27 have friends ['26', '2', '28'] in common
# Dolphins 18 and 28 have friends ['26', '2'] in common
# Dolphins 18 and 29 have friends ['2'] in common
# Dolphins 18 and 30 have friends [] in common
# Dolphins 18 and 31 have friends [] in common
# Dolphins 18 and 32 have friends [] in common
# Dolphins 18 and 33 have friends ['10', '14'] in common
# Dolphins 18 and 13 have friends [] in common
# Dolphins 18 and 34 have friends [] in common
# Dolphins 18 and 35 have friends [] in common
# Dolphins 18 and 36 have friends [] in common
# Dolphins 18 and 37 have friends ['2'] in common
# Dolphins 18 and 24 have friends [] in common
# Dolphins 18 and 38 have friends [] in common
# Dolphins 18 and 39 have friends [] in common
# Dolphins 18 and 40 have friends ['58'] in common
# Dolphins 18 and 41 have friends [] in common
# Dolphins 18 and 42 have friends ['10', '58', '14', '2'] in common
# Dolphins 18 and 43 have friends [] in common
# Dolphins 18 and 44 have friends [] in common
# Dolphins 18 and 45 have friends [] in common
# Dolphins 18 and 46 have friends [] in common
# Dolphins 18 and 47 have friends [] in common
# Dolphins 18 and 48 have friends [] in common
# Dolphins 18 and 50 have friends [] in common
# Dolphins 18 and 51 have friends [] in common
# Dolphins 18 and 5 have friends [] in common
# Dolphins 18 and 52 have friends [] in common
# Dolphins 18 and 12 have friends [] in common
# Dolphins 18 and 53 have friends [] in common
# Dolphins 18 and 54 have friends [] in common
# Dolphins 18 and 55 have friends ['58', '14', '2', '7'] in common
# Dolphins 18 and 56 have friends [] in common
# Dolphins 18 and 57 have friends ['7'] in common
# Dolphins 18 and 58 have friends ['10', '14', '7'] in common
# Dolphins 18 and 49 have friends ['58'] in common
# Dolphins 18 and 59 have friends [] in common
# Dolphins 18 and 60 have friends [] in common
# Dolphins 18 and 61 have friends [] in common
# Dolphins 18 and 62 have friends [] in common
# Dolphins 19 and 4 have friends [] in common
# Dolphins 19 and 9 have friends ['46', '21'] in common
# Dolphins 19 and 6 have friends [] in common
# Dolphins 19 and 10 have friends [] in common
# Dolphins 19 and 7 have friends [] in common
# Dolphins 19 and 1 have friends ['16'] in common
# Dolphins 19 and 11 have friends ['30'] in common
# Dolphins 19 and 3 have friends [] in common
# Dolphins 19 and 14 have friends [] in common
# Dolphins 19 and 15 have friends ['25'] in common
# Dolphins 19 and 16 have friends ['46', '25'] in common
# Dolphins 19 and 17 have friends ['21'] in common
# Dolphins 19 and 2 have friends [] in common
# Dolphins 19 and 18 have friends [] in common
# Dolphins 19 and 19 have friends ['30', '22', '52', '25', '21', '16', '46'] in common
# Dolphins 19 and 20 have friends [] in common
# Dolphins 19 and 8 have friends [] in common
# Dolphins 19 and 21 have friends [] in common
# Dolphins 19 and 22 have friends ['46', '52', '30'] in common
# Dolphins 19 and 23 have friends [] in common
# Dolphins 19 and 25 have friends ['16', '52', '30', '46'] in common
# Dolphins 19 and 26 have friends [] in common
# Dolphins 19 and 27 have friends [] in common
# Dolphins 19 and 28 have friends [] in common
# Dolphins 19 and 29 have friends ['21'] in common
# Dolphins 19 and 30 have friends ['46', '25', '22', '52'] in common
# Dolphins 19 and 31 have friends [] in common
# Dolphins 19 and 32 have friends [] in common
# Dolphins 19 and 33 have friends [] in common
# Dolphins 19 and 13 have friends [] in common
# Dolphins 19 and 34 have friends ['22'] in common
# Dolphins 19 and 35 have friends [] in common
# Dolphins 19 and 36 have friends ['30'] in common
# Dolphins 19 and 37 have friends ['21'] in common
# Dolphins 19 and 24 have friends ['46', '52'] in common
# Dolphins 19 and 38 have friends ['46', '22'] in common
# Dolphins 19 and 39 have friends ['21'] in common
# Dolphins 19 and 40 have friends [] in common
# Dolphins 19 and 41 have friends ['16'] in common
# Dolphins 19 and 42 have friends [] in common
# Dolphins 19 and 43 have friends [] in common
# Dolphins 19 and 44 have friends ['30'] in common
# Dolphins 19 and 45 have friends ['21'] in common
# Dolphins 19 and 46 have friends ['30', '22', '52', '25', '16'] in common
# Dolphins 19 and 47 have friends [] in common
# Dolphins 19 and 48 have friends ['21'] in common
# Dolphins 19 and 50 have friends [] in common
# Dolphins 19 and 51 have friends ['46', '52', '21'] in common
# Dolphins 19 and 5 have friends ['52'] in common
# Dolphins 19 and 52 have friends ['46', '25', '22', '30'] in common
# Dolphins 19 and 12 have friends ['52'] in common
# Dolphins 19 and 53 have friends ['30'] in common
# Dolphins 19 and 54 have friends [] in common
# Dolphins 19 and 55 have friends [] in common
# Dolphins 19 and 56 have friends ['16', '52'] in common
# Dolphins 19 and 57 have friends [] in common
# Dolphins 19 and 58 have friends [] in common
# Dolphins 19 and 49 have friends [] in common
# Dolphins 19 and 59 have friends [] in common
# Dolphins 19 and 60 have friends ['16', '46'] in common
# Dolphins 19 and 61 have friends [] in common
# Dolphins 19 and 62 have friends [] in common
# Dolphins 20 and 4 have friends [] in common
# Dolphins 20 and 9 have friends [] in common
# Dolphins 20 and 6 have friends [] in common
# Dolphins 20 and 10 have friends [] in common
# Dolphins 20 and 7 have friends ['55'] in common
# Dolphins 20 and 1 have friends [] in common
# Dolphins 20 and 11 have friends [] in common
# Dolphins 20 and 3 have friends [] in common
# Dolphins 20 and 14 have friends ['55'] in common
# Dolphins 20 and 15 have friends [] in common
# Dolphins 20 and 16 have friends [] in common
# Dolphins 20 and 17 have friends [] in common
# Dolphins 20 and 2 have friends ['55'] in common
# Dolphins 20 and 18 have friends ['2'] in common
# Dolphins 20 and 19 have friends [] in common
# Dolphins 20 and 20 have friends ['8', '31', '2', '55'] in common
# Dolphins 20 and 8 have friends ['31', '55'] in common
# Dolphins 20 and 21 have friends [] in common
# Dolphins 20 and 22 have friends [] in common
# Dolphins 20 and 23 have friends [] in common
# Dolphins 20 and 25 have friends [] in common
# Dolphins 20 and 26 have friends [] in common
# Dolphins 20 and 27 have friends ['2'] in common
# Dolphins 20 and 28 have friends ['8', '2'] in common
# Dolphins 20 and 29 have friends ['31', '2'] in common
# Dolphins 20 and 30 have friends [] in common
# Dolphins 20 and 31 have friends ['8'] in common
# Dolphins 20 and 32 have friends [] in common
# Dolphins 20 and 33 have friends [] in common
# Dolphins 20 and 13 have friends [] in common
# Dolphins 20 and 34 have friends [] in common
# Dolphins 20 and 35 have friends [] in common
# Dolphins 20 and 36 have friends [] in common
# Dolphins 20 and 37 have friends ['2'] in common
# Dolphins 20 and 24 have friends [] in common
# Dolphins 20 and 38 have friends [] in common
# Dolphins 20 and 39 have friends [] in common
# Dolphins 20 and 40 have friends [] in common
# Dolphins 20 and 41 have friends ['8'] in common
# Dolphins 20 and 42 have friends ['2', '55'] in common
# Dolphins 20 and 43 have friends ['31'] in common
# Dolphins 20 and 44 have friends [] in common
# Dolphins 20 and 45 have friends [] in common
# Dolphins 20 and 46 have friends [] in common
# Dolphins 20 and 47 have friends [] in common
# Dolphins 20 and 48 have friends ['31'] in common
# Dolphins 20 and 50 have friends [] in common
# Dolphins 20 and 51 have friends [] in common
# Dolphins 20 and 5 have friends [] in common
# Dolphins 20 and 52 have friends [] in common
# Dolphins 20 and 12 have friends [] in common
# Dolphins 20 and 53 have friends [] in common
# Dolphins 20 and 54 have friends [] in common
# Dolphins 20 and 55 have friends ['8', '2'] in common
# Dolphins 20 and 56 have friends [] in common
# Dolphins 20 and 57 have friends [] in common
# Dolphins 20 and 58 have friends ['55'] in common
# Dolphins 20 and 49 have friends [] in common
# Dolphins 20 and 59 have friends [] in common
# Dolphins 20 and 60 have friends [] in common
# Dolphins 20 and 61 have friends [] in common
# Dolphins 20 and 62 have friends [] in common
# Dolphins 8 and 4 have friends [] in common
# Dolphins 8 and 9 have friends [] in common
# Dolphins 8 and 6 have friends [] in common
# Dolphins 8 and 10 have friends [] in common
# Dolphins 8 and 7 have friends ['55'] in common
# Dolphins 8 and 1 have friends ['41'] in common
# Dolphins 8 and 11 have friends [] in common
# Dolphins 8 and 3 have friends [] in common
# Dolphins 8 and 14 have friends ['55'] in common
# Dolphins 8 and 15 have friends ['41'] in common
# Dolphins 8 and 16 have friends ['41'] in common
# Dolphins 8 and 17 have friends [] in common
# Dolphins 8 and 2 have friends ['20', '55', '28'] in common
# ...
# Dolphins 58 and 30 have friends [] in common
# Dolphins 58 and 31 have friends [] in common
# Dolphins 58 and 32 have friends ['18'] in common
# Dolphins 58 and 33 have friends ['10', '14'] in common
# Dolphins 58 and 13 have friends [] in common
# Dolphins 58 and 34 have friends [] in common
# Dolphins 58 and 35 have friends [] in common
# Dolphins 58 and 36 have friends [] in common
# Dolphins 58 and 37 have friends ['40'] in common
# Dolphins 58 and 24 have friends [] in common
# Dolphins 58 and 38 have friends [] in common
# Dolphins 58 and 39 have friends [] in common
# Dolphins 58 and 40 have friends [] in common
# Dolphins 58 and 41 have friends [] in common
# Dolphins 58 and 42 have friends ['10', '14', '55'] in common
# Dolphins 58 and 43 have friends [] in common
# Dolphins 58 and 44 have friends [] in common
# Dolphins 58 and 45 have friends [] in common
# Dolphins 58 and 46 have friends [] in common
# Dolphins 58 and 47 have friends [] in common
# Dolphins 58 and 48 have friends [] in common
# Dolphins 58 and 50 have friends [] in common
# Dolphins 58 and 51 have friends [] in common
# Dolphins 58 and 5 have friends [] in common
# Dolphins 58 and 52 have friends [] in common
# Dolphins 58 and 12 have friends [] in common
# Dolphins 58 and 53 have friends [] in common
# Dolphins 58 and 54 have friends [] in common
# Dolphins 58 and 55 have friends ['14', '7', '42'] in common
# Dolphins 58 and 56 have friends [] in common
# Dolphins 58 and 57 have friends ['6', '7'] in common
# Dolphins 58 and 58 have friends ['14', '55', '10', '18', '6', '40', '49', '42', '7'] in common
# Dolphins 58 and 49 have friends [] in common
# Dolphins 58 and 59 have friends [] in common
# Dolphins 58 and 60 have friends [] in common
# Dolphins 58 and 61 have friends [] in common
# Dolphins 58 and 62 have friends [] in common
# Dolphins 49 and 4 have friends [] in common
# Dolphins 49 and 9 have friends [] in common
# Dolphins 49 and 6 have friends ['58'] in common
# Dolphins 49 and 10 have friends ['58'] in common
# Dolphins 49 and 7 have friends ['58'] in common
# Dolphins 49 and 1 have friends [] in common
# Dolphins 49 and 11 have friends [] in common
# Dolphins 49 and 3 have friends [] in common
# Dolphins 49 and 14 have friends ['58'] in common
# Dolphins 49 and 15 have friends [] in common
# Dolphins 49 and 16 have friends [] in common
# Dolphins 49 and 17 have friends [] in common
# Dolphins 49 and 2 have friends [] in common
# Dolphins 49 and 18 have friends ['58'] in common
# Dolphins 49 and 19 have friends [] in common
# Dolphins 49 and 20 have friends [] in common
# Dolphins 49 and 8 have friends [] in common
# Dolphins 49 and 21 have friends [] in common
# Dolphins 49 and 22 have friends [] in common
# Dolphins 49 and 23 have friends [] in common
# Dolphins 49 and 25 have friends [] in common
# Dolphins 49 and 26 have friends [] in common
# Dolphins 49 and 27 have friends [] in common
# Dolphins 49 and 28 have friends [] in common
# Dolphins 49 and 29 have friends [] in common
# Dolphins 49 and 30 have friends [] in common
# Dolphins 49 and 31 have friends [] in common
# Dolphins 49 and 32 have friends [] in common
# Dolphins 49 and 33 have friends [] in common
# Dolphins 49 and 13 have friends [] in common
# Dolphins 49 and 34 have friends [] in common
# Dolphins 49 and 35 have friends [] in common
# Dolphins 49 and 36 have friends [] in common
# Dolphins 49 and 37 have friends [] in common
# Dolphins 49 and 24 have friends [] in common
# Dolphins 49 and 38 have friends [] in common
# Dolphins 49 and 39 have friends [] in common
# Dolphins 49 and 40 have friends ['58'] in common
# Dolphins 49 and 41 have friends [] in common
# Dolphins 49 and 42 have friends ['58'] in common
# Dolphins 49 and 43 have friends [] in common
# Dolphins 49 and 44 have friends [] in common
# Dolphins 49 and 45 have friends [] in common
# Dolphins 49 and 46 have friends [] in common
# Dolphins 49 and 47 have friends [] in common
# Dolphins 49 and 48 have friends [] in common
# Dolphins 49 and 50 have friends [] in common
# Dolphins 49 and 51 have friends [] in common
# Dolphins 49 and 5 have friends [] in common
# Dolphins 49 and 52 have friends [] in common
# Dolphins 49 and 12 have friends [] in common
# Dolphins 49 and 53 have friends [] in common
# Dolphins 49 and 54 have friends [] in common
# Dolphins 49 and 55 have friends ['58'] in common
# Dolphins 49 and 56 have friends [] in common
# Dolphins 49 and 57 have friends [] in common
# Dolphins 49 and 58 have friends [] in common
# Dolphins 49 and 49 have friends ['58'] in common
# Dolphins 49 and 59 have friends [] in common
# Dolphins 49 and 60 have friends [] in common
# Dolphins 49 and 61 have friends [] in common
# Dolphins 49 and 62 have friends [] in common
# Dolphins 59 and 4 have friends [] in common
# Dolphins 59 and 9 have friends [] in common
# Dolphins 59 and 6 have friends [] in common
# Dolphins 59 and 10 have friends [] in common
# Dolphins 59 and 7 have friends [] in common
# Dolphins 59 and 1 have friends [] in common
# Dolphins 59 and 11 have friends [] in common
# Dolphins 59 and 3 have friends [] in common
# Dolphins 59 and 14 have friends [] in common
# Dolphins 59 and 15 have friends ['39'] in common
# Dolphins 59 and 16 have friends [] in common
# Dolphins 59 and 17 have friends ['39'] in common
# Dolphins 59 and 2 have friends [] in common
# Dolphins 59 and 18 have friends [] in common
# Dolphins 59 and 19 have friends [] in common
# Dolphins 59 and 20 have friends [] in common
# Dolphins 59 and 8 have friends [] in common
# Dolphins 59 and 21 have friends ['39'] in common
# Dolphins 59 and 22 have friends [] in common
# Dolphins 59 and 23 have friends [] in common
# Dolphins 59 and 25 have friends [] in common
# Dolphins 59 and 26 have friends [] in common
# Dolphins 59 and 27 have friends [] in common
# Dolphins 59 and 28 have friends [] in common
# Dolphins 59 and 29 have friends [] in common
# Dolphins 59 and 30 have friends [] in common
# Dolphins 59 and 31 have friends [] in common
# Dolphins 59 and 32 have friends [] in common
# Dolphins 59 and 33 have friends [] in common
# Dolphins 59 and 13 have friends [] in common
# Dolphins 59 and 34 have friends ['39'] in common
# Dolphins 59 and 35 have friends [] in common
# Dolphins 59 and 36 have friends [] in common
# Dolphins 59 and 37 have friends [] in common
# Dolphins 59 and 24 have friends [] in common
# Dolphins 59 and 38 have friends [] in common
# Dolphins 59 and 39 have friends [] in common
# Dolphins 59 and 40 have friends [] in common
# Dolphins 59 and 41 have friends [] in common
# Dolphins 59 and 42 have friends [] in common
# Dolphins 59 and 43 have friends [] in common
# Dolphins 59 and 44 have friends ['39'] in common
# Dolphins 59 and 45 have friends ['39'] in common
# Dolphins 59 and 46 have friends [] in common
# Dolphins 59 and 47 have friends [] in common
# Dolphins 59 and 48 have friends [] in common
# Dolphins 59 and 50 have friends [] in common
# Dolphins 59 and 51 have friends [] in common
# Dolphins 59 and 5 have friends [] in common
# Dolphins 59 and 52 have friends [] in common
# Dolphins 59 and 12 have friends [] in common
# Dolphins 59 and 53 have friends ['39'] in common
# Dolphins 59 and 54 have friends [] in common
# Dolphins 59 and 55 have friends [] in common
# Dolphins 59 and 56 have friends [] in common
# Dolphins 59 and 57 have friends [] in common
# Dolphins 59 and 58 have friends [] in common
# Dolphins 59 and 49 have friends [] in common
# Dolphins 59 and 59 have friends ['39'] in common
# Dolphins 59 and 60 have friends [] in common
# Dolphins 59 and 61 have friends [] in common
# Dolphins 59 and 62 have friends [] in common
# Dolphins 60 and 4 have friends ['9'] in common
# Dolphins 60 and 9 have friends ['46', '4'] in common
# Dolphins 60 and 6 have friends [] in common
# Dolphins 60 and 10 have friends [] in common
# Dolphins 60 and 7 have friends [] in common
# Dolphins 60 and 1 have friends ['16'] in common
# Dolphins 60 and 11 have friends [] in common
# Dolphins 60 and 3 have friends [] in common
# Dolphins 60 and 14 have friends [] in common
# Dolphins 60 and 15 have friends ['4'] in common
# Dolphins 60 and 16 have friends ['46'] in common
# Dolphins 60 and 17 have friends [] in common
# Dolphins 60 and 2 have friends ['37'] in common
# Dolphins 60 and 18 have friends [] in common
# Dolphins 60 and 19 have friends ['16', '46'] in common
# Dolphins 60 and 20 have friends [] in common
# Dolphins 60 and 8 have friends [] in common
# Dolphins 60 and 21 have friends ['9', '37'] in common
# Dolphins 60 and 22 have friends ['46'] in common
# Dolphins 60 and 23 have friends [] in common
# Dolphins 60 and 25 have friends ['16', '46'] in common
# Dolphins 60 and 26 have friends [] in common
# Dolphins 60 and 27 have friends [] in common
# Dolphins 60 and 28 have friends [] in common
# Dolphins 60 and 29 have friends ['9'] in common
# Dolphins 60 and 30 have friends ['46'] in common
# Dolphins 60 and 31 have friends [] in common
# Dolphins 60 and 32 have friends [] in common
# Dolphins 60 and 33 have friends [] in common
# Dolphins 60 and 13 have friends [] in common
# Dolphins 60 and 34 have friends [] in common
# Dolphins 60 and 35 have friends [] in common
# Dolphins 60 and 36 have friends [] in common
# Dolphins 60 and 37 have friends [] in common
# Dolphins 60 and 24 have friends ['46', '37'] in common
# Dolphins 60 and 38 have friends ['46', '9', '37'] in common
# Dolphins 60 and 39 have friends [] in common
# Dolphins 60 and 40 have friends ['37'] in common
# Dolphins 60 and 41 have friends ['16', '37'] in common
# Dolphins 60 and 42 have friends [] in common
# Dolphins 60 and 43 have friends [] in common
# Dolphins 60 and 44 have friends [] in common
# Dolphins 60 and 45 have friends [] in common
# Dolphins 60 and 46 have friends ['16', '9'] in common
# Dolphins 60 and 47 have friends [] in common
# Dolphins 60 and 48 have friends [] in common
# Dolphins 60 and 50 have friends [] in common
# Dolphins 60 and 51 have friends ['46'] in common
# Dolphins 60 and 5 have friends [] in common
# Dolphins 60 and 52 have friends ['46'] in common
# Dolphins 60 and 12 have friends [] in common
# Dolphins 60 and 53 have friends [] in common
# Dolphins 60 and 54 have friends [] in common
# Dolphins 60 and 55 have friends [] in common
# Dolphins 60 and 56 have friends ['16'] in common
# Dolphins 60 and 57 have friends [] in common
# Dolphins 60 and 58 have friends [] in common
# Dolphins 60 and 49 have friends [] in common
# Dolphins 60 and 59 have friends [] in common
# Dolphins 60 and 60 have friends ['4', '9', '16', '37', '46'] in common
# Dolphins 60 and 61 have friends [] in common
# Dolphins 60 and 62 have friends [] in common
# Dolphins 61 and 4 have friends [] in common
# Dolphins 61 and 9 have friends [] in common
# Dolphins 61 and 6 have friends [] in common
# Dolphins 61 and 10 have friends ['33'] in common
# Dolphins 61 and 7 have friends [] in common
# Dolphins 61 and 1 have friends [] in common
# Dolphins 61 and 11 have friends [] in common
# Dolphins 61 and 3 have friends [] in common
# Dolphins 61 and 14 have friends ['33'] in common
# Dolphins 61 and 15 have friends [] in common
# Dolphins 61 and 16 have friends [] in common
# Dolphins 61 and 17 have friends [] in common
# Dolphins 61 and 2 have friends [] in common
# Dolphins 61 and 18 have friends [] in common
# Dolphins 61 and 19 have friends [] in common
# Dolphins 61 and 20 have friends [] in common
# Dolphins 61 and 8 have friends [] in common
# Dolphins 61 and 21 have friends [] in common
# Dolphins 61 and 22 have friends [] in common
# Dolphins 61 and 23 have friends [] in common
# Dolphins 61 and 25 have friends [] in common
# Dolphins 61 and 26 have friends [] in common
# Dolphins 61 and 27 have friends [] in common
# Dolphins 61 and 28 have friends [] in common
# Dolphins 61 and 29 have friends [] in common
# Dolphins 61 and 30 have friends [] in common
# Dolphins 61 and 31 have friends [] in common
# Dolphins 61 and 32 have friends [] in common
# Dolphins 61 and 33 have friends [] in common
# Dolphins 61 and 13 have friends [] in common
# Dolphins 61 and 34 have friends [] in common
# Dolphins 61 and 35 have friends [] in common
# Dolphins 61 and 36 have friends [] in common
# Dolphins 61 and 37 have friends [] in common
# Dolphins 61 and 24 have friends [] in common
# Dolphins 61 and 38 have friends [] in common
# Dolphins 61 and 39 have friends [] in common
# Dolphins 61 and 40 have friends [] in common
# Dolphins 61 and 41 have friends [] in common
# Dolphins 61 and 42 have friends [] in common
# Dolphins 61 and 43 have friends [] in common
# Dolphins 61 and 44 have friends [] in common
# Dolphins 61 and 45 have friends [] in common
# Dolphins 61 and 46 have friends [] in common
# Dolphins 61 and 47 have friends [] in common
# Dolphins 61 and 48 have friends [] in common
# Dolphins 61 and 50 have friends [] in common
# Dolphins 61 and 51 have friends [] in common
# Dolphins 61 and 5 have friends [] in common
# Dolphins 61 and 52 have friends [] in common
# Dolphins 61 and 12 have friends [] in common
# Dolphins 61 and 53 have friends [] in common
# Dolphins 61 and 54 have friends [] in common
# Dolphins 61 and 55 have friends [] in common
# Dolphins 61 and 56 have friends [] in common
# Dolphins 61 and 57 have friends [] in common
# Dolphins 61 and 58 have friends [] in common
# Dolphins 61 and 49 have friends [] in common
# Dolphins 61 and 59 have friends [] in common
# Dolphins 61 and 60 have friends [] in common
# Dolphins 61 and 61 have friends ['33'] in common
# Dolphins 61 and 62 have friends [] in common
# Dolphins 62 and 4 have friends [] in common
# Dolphins 62 and 9 have friends ['38'] in common
# Dolphins 62 and 6 have friends [] in common
# Dolphins 62 and 10 have friends [] in common
# Dolphins 62 and 7 have friends [] in common
# Dolphins 62 and 1 have friends [] in common
# Dolphins 62 and 11 have friends ['3'] in common
# Dolphins 62 and 3 have friends [] in common
# Dolphins 62 and 14 have friends [] in common
# Dolphins 62 and 15 have friends ['38'] in common
# Dolphins 62 and 16 have friends [] in common
# Dolphins 62 and 17 have friends ['38'] in common
# Dolphins 62 and 2 have friends [] in common
# Dolphins 62 and 18 have friends [] in common
# Dolphins 62 and 19 have friends [] in common
# Dolphins 62 and 20 have friends [] in common
# Dolphins 62 and 8 have friends [] in common
# Dolphins 62 and 21 have friends [] in common
# Dolphins 62 and 22 have friends ['38'] in common
# Dolphins 62 and 23 have friends [] in common
# Dolphins 62 and 25 have friends [] in common
# Dolphins 62 and 26 have friends [] in common
# Dolphins 62 and 27 have friends [] in common
# Dolphins 62 and 28 have friends [] in common
# Dolphins 62 and 29 have friends [] in common
# Dolphins 62 and 30 have friends [] in common
# Dolphins 62 and 31 have friends [] in common
# Dolphins 62 and 32 have friends [] in common
# Dolphins 62 and 33 have friends [] in common
# Dolphins 62 and 13 have friends [] in common
# Dolphins 62 and 34 have friends ['38'] in common
# Dolphins 62 and 35 have friends ['38'] in common
# Dolphins 62 and 36 have friends [] in common
# Dolphins 62 and 37 have friends ['38'] in common
# Dolphins 62 and 24 have friends [] in common
# Dolphins 62 and 38 have friends [] in common
# Dolphins 62 and 39 have friends [] in common
# Dolphins 62 and 40 have friends [] in common
# Dolphins 62 and 41 have friends ['38'] in common
# Dolphins 62 and 42 have friends [] in common
# Dolphins 62 and 43 have friends ['3'] in common
# Dolphins 62 and 44 have friends ['38', '54'] in common
# Dolphins 62 and 45 have friends ['3'] in common
# Dolphins 62 and 46 have friends ['38'] in common
# Dolphins 62 and 47 have friends [] in common
# Dolphins 62 and 48 have friends [] in common
# Dolphins 62 and 50 have friends [] in common
# Dolphins 62 and 51 have friends [] in common
# Dolphins 62 and 5 have friends [] in common
# Dolphins 62 and 52 have friends [] in common
# Dolphins 62 and 12 have friends [] in common
# Dolphins 62 and 53 have friends [] in common
# Dolphins 62 and 54 have friends [] in common
# Dolphins 62 and 55 have friends [] in common
# Dolphins 62 and 56 have friends [] in common
# Dolphins 62 and 57 have friends [] in common
# Dolphins 62 and 58 have friends [] in common
# Dolphins 62 and 49 have friends [] in common
# Dolphins 62 and 59 have friends [] in common
# Dolphins 62 and 60 have friends [] in common
# Dolphins 62 and 61 have friends [] in common
# Dolphins 62 and 62 have friends ['38', '3', '54'] in common
